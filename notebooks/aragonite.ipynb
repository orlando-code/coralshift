# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

sys.path.append("../")

# %%
from __future__ import annotations

from pathlib import Path
import xarray as xa
import numpy as np
import math as m
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn import model_selection
from scipy.interpolate import interp2d

import rasterio
from rasterio.plot import show
import rioxarray as rio

# %%
bath_A = rio.open_rasterio(
        rasterio.open("/Volumes/MRes Drive/bathymetry/GBR_30m/Great_Barrier_Reef_A_2020_30m_MSL_cog.tif"),
        ).rename("bathymetry_A")

# %%
bath_A
# Out:
# <xarray.DataArray 'bathymetry_A' (band: 1, y: 23333, x: 16666)>
# [388867778 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 142.0 142.0 142.0 142.0 ... 147.0 147.0 147.0 147.0
#   * y            (y) float64 -10.0 -10.0 -10.0 -10.0 ... -17.0 -17.0 -17.0 -17.0
#     spatial_ref  int64 0
# Attributes:
#     AREA_OR_POINT:             Area
#     STATISTICS_APPROXIMATE:    YES
#     STATISTICS_MAXIMUM:        1303.0440673828
#     STATISTICS_MEAN:           -907.48369601852
#     STATISTICS_MINIMUM:        -3966.3754882812
#     STATISTICS_STDDEV:         1232.3205393338
#     STATISTICS_VALID_PERCENT:  100
#     _FillValue:                -9999.0
#     scale_factor:              1.0
#     add_offset:                0.0

# %%
# Create the NaN-filled array
data = np.full((23333, 16666), np.nan)

# Create x and y coordinate arrays
x_coords = np.arange(16666)
y_coords = np.arange(23333)

# Create the xarray dataset
dataset = xa.Dataset(
    {"band": (["y", "x"], data)},
    coords={"x": x_coords, "y": y_coords},
)

# Save the dataset to a netCDF file
dataset.to_netcdf("/Volumes/MRes Drive/bathymetry/GBR_30m/nan_values_dataset.nc")

# %%
dataset
# Out:
# <xarray.Dataset>
# Dimensions:  (y: 23333, x: 16666)
# Coordinates:
#   * x        (x) int64 0 1 2 3 4 5 6 ... 16660 16661 16662 16663 16664 16665
#   * y        (y) int64 0 1 2 3 4 5 6 ... 23327 23328 23329 23330 23331 23332
# Data variables:
#     band     (y, x) float64 nan nan nan nan nan nan ... nan nan nan nan nan nan

# %%
bath_A.to_netcdf("/Volumes/MRes Drive/bathymetry/GBR_30m/Great_Barrier_Reef_A_2020_30m_MSL_cog.nc")

# %%
rio.open_rasterio(
        rasterio.open("/Volumes/MRes Drive/ocean_acidification/TREND09-4M-corals.eps.75dpi.tif"),
        ).rename("aragonite_saturation")
# Out:
# /Users/orlandotimmerman/miniconda3/envs/coralshift/lib/python3.11/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# /Users/orlandotimmerman/miniconda3/envs/coralshift/lib/python3.11/site-packages/rioxarray/_io.py:1126: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   warnings.warn(str(rio_warning.message), type(rio_warning.message))  # type: ignore
# <xarray.DataArray 'aragonite_saturation' (band: 3, y: 2419, x: 1843)>
# [13374651 values with dtype=uint8]
# Coordinates:
#   * band         (band) int64 1 2 3
#   * x            (x) float64 0.5 1.5 2.5 3.5 ... 1.84e+03 1.842e+03 1.842e+03
#   * y            (y) float64 0.5 1.5 2.5 3.5 ... 2.416e+03 2.418e+03 2.418e+03
#     spatial_ref  int64 0
# Attributes:
#     scale_factor:  1.0
# ...
